# %%
# Input a newick file
# Get just the tip names
# in this case, tip names are just NCBI IDs
# From NCBI get the species name
# Replace the NCBI ID in the newick with the Species name
# Save file.

# %%
# Imports
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import sys; 
#from ete3 import Tree; 
import argparse
from Bio import Entrez
import time
import json
import csv
from collections import Counter
from ete3 import NCBITaxa
import pandas as pd

# %%
# Declares, load newick string
DATA_DICT = {}
Entrez.email = "aglucaci@gmail.com"
TREE_FILE = "../../results/BDNF_Codons.fa_CODON_AWARE_ALN.fasta.treefile"
with open(TREE_FILE, "r") as fh:
    TREE_NEWICK = fh.read()

#TREE_NEWICK = ""
TREE_NEWICK
# Out:
# '(XM_012452239.1:0.0000030656,((((((((((((((((((XM_011964726.1:0.0000028746,((XM_012031702.1:0.0000024641,XM_012031697.1:0.0000021148):0.0346338799,XM_011964715.1:0.0687779586):0.0346609895):0.0000021310,XM_011964723.1:0.0000028746):0.0000021123,XM_011964717.1:0.0000025534):0.0344929712,(((((((XM_012649562.1:0.0000028746,((((((XM_020286536.1:0.0000023879,XM_020286535.1:1.9845464578):0.0000030105,XM_020286537.1:0.0000028746):1.0262411980,XM_020286540.1:0.0000028746):0.0000025907,XM_020286534.1:0.0000030558):0.5299750950,XM_012649557.1:0.0000024136):0.0000022739,XM_012649566.1:0.0000028746):0.0000022577):1.0533403740,XM_012649558.1:0.0000021562):0.5852112102,((((((((XM_008050728.1:0.0000029392,XM_021708951.1:0.0000024154):4.4796307040,((((((((XM_012031699.1:0.0000021155,(XM_011964718.1:0.0000024852,(XM_003254349.2:0.1499695125,XM_009246511.2:0.2276184747):0.6163445235):0.0743714629):0.6179175643,XM_012031705.1:0.0000022134):0.0000023681,XM_012031700.1:0.0000021925):0.5553357837,XM_011964719.1:0.0000021662):0.0087884909,XM_011964716.1:0.0000022063):0.3680226900,XM_011936308.1:0.2834833452):0.3247743807,((XM_034932318.1:0.0000021339,XM_008955891.2:0.0064624258):0.0295656349,((((NM_001143810.2:0.0000028746,XM_011520280.2:0.0000028746):0.0000025528,NM_001709.5:0.0000027902):0.0000026441,NM_001143813.2:0.0000028746):0.2318995017,XM_004050851.2:0.1086660629):0.0262348671):0.1513699919):0.0267012419,XM_009007854.3:0.3412768889):0.6017021852):0.3029712473,(((((((((((XM_013019595.1:0.0000028746,(XM_013019596.1:0.0000023172,XM_013019592.1:0.0066414928):0.0000022799):0.0000025572,XM_013019593.1:0.0000025436):5.3807509070,XM_020177315.1:1.5216167775):0.7174932634,XM_015476449.1:1.0481139798):0.0369776880,((((XM_031944161.1:0.0000022920,(XM_023506303.2:0.0000028746,XM_031944159.1:0.0000027340):0.0000030336):2.6076972590,((((XM_027852578.1:0.0000028746,XM_027852579.1:0.0000027574):1.0352627830,(((XM_020977978.1:0.0000028746,XM_020977976.1:0.1097406717):0.0000028952,XM_020977979.1:0.0000028746):0.0000026577,XM_020977977.1:0.0000024331):3.3814799900):0.7481545477,XM_036763631.1:1.7171525194):0.8856917361,((XM_007497196.2:0.0000028590,XM_007497203.2:0.0000028746):0.0000029891,XM_007497199.2:0.0000027342):3.2889066640):0.6198198697):3.3231782790,(XM_029059317.2:0.0000031402,XM_029059318.2:0.0000026212):10.5448518100):6.5554018970,((((XM_008851139.2:0.0000028746,((XM_029555093.1:0.0000025086,XM_008851155.2:0.0000028746):0.0000022606,XM_008851150.2:0.0000028746):0.0000025857):0.0000024586,XM_029555090.1:0.0000026115):2.8864114670,((((XM_003512747.5:0.0000028746,XM_035436972.1:0.0000028746):0.2813151857,((XM_007653166.4:0.0524993818,XM_035436971.1:0.0000026863):0.0000021292,XM_007653168.4:0.0060264930):0.0915326150):0.8152500337,XM_037204438.1:0.6216385987):0.3243359385,((((XM_031371316.1:0.0000028746,(XM_031371317.1:0.0000028746,XM_031371314.1:0.0000031019):0.0000012950):0.0682237360,XM_031371315.1:0.0000028746):0.0000023945,XM_031371313.1:0.0000029047):0.4412200787,(((((XM_006234684.4:0.0000021190,XM_032903862.1:0.2291724703):0.0000029009,NM_001270631.1:0.0000028746):0.0000028919,NM_001270634.1:0.0000026289):0.9793373658,((((((NM_001048142.1:0.0000028746,NM_007540.4:0.0017925861):0.0786386773,NM_001285422.1:0.0000030849):0.0154188674,XM_021151236.2:0.0562077964):0.0499447729,XM_021192829.2:0.2407221219):0.5639609747,(((XM_032903864.1:0.0000028746,XM_032903863.1:0.0946198348):0.0000029079,XM_032903866.1:0.0000028746):0.0000024220,XM_032903861.1:0.0000022322):0.0642666900):0.0405335376,NM_001270630.1:0.0448392586):3.2155624100):0.0000026015,NM_012513.4:0.0000021334):5.1860716840):0.3282413007):0.3710923608):1.0314800710,((XM_004660850.2:0.0000028746,XM_004660847.2:0.0000028746):0.0000025290,XM_004660846.2:0.0000023375):5.1855766410):0.6552514014):0.4707934203):0.5149562032,(((XM_036258710.1:0.0000028746,XM_036258708.1:0.0047640365):0.0000029692,XM_036258709.1:0.0000022582):0.0016704439,XM_036258707.1:0.0000030131):0.7106426637):0.4897347853,((XM_017 ...

# %%
DATA_DICT = {}

def main(TREE_NEWICK):
    global DATA_DICT
    t = Tree(TREE_NEWICK, format=1)
    count = 1
    for n, ACCESSION in enumerate(t.get_leaf_names()):
        print(n+1, "# Checking ACCESION:", ACCESSION)
main(TREE_NEWICK)
# Out:
# 1 # Checking ACCESION: XM_012452239.1
# 2 # Checking ACCESION: XM_011964726.1
# 3 # Checking ACCESION: XM_012031702.1
# 4 # Checking ACCESION: XM_012031697.1
# 5 # Checking ACCESION: XM_011964715.1
# 6 # Checking ACCESION: XM_011964723.1
# 7 # Checking ACCESION: XM_011964717.1
# 8 # Checking ACCESION: XM_012649562.1
# 9 # Checking ACCESION: XM_020286536.1
# 10 # Checking ACCESION: XM_020286535.1
# 11 # Checking ACCESION: XM_020286537.1
# 12 # Checking ACCESION: XM_020286540.1
# 13 # Checking ACCESION: XM_020286534.1
# 14 # Checking ACCESION: XM_012649557.1
# 15 # Checking ACCESION: XM_012649566.1
# 16 # Checking ACCESION: XM_012649558.1
# 17 # Checking ACCESION: XM_008050728.1
# 18 # Checking ACCESION: XM_021708951.1
# 19 # Checking ACCESION: XM_012031699.1
# 20 # Checking ACCESION: XM_011964718.1
# 21 # Checking ACCESION: XM_003254349.2
# 22 # Checking ACCESION: XM_009246511.2
# 23 # Checking ACCESION: XM_012031705.1
# 24 # Checking ACCESION: XM_012031700.1
# 25 # Checking ACCESION: XM_011964719.1
# 26 # Checking ACCESION: XM_011964716.1
# 27 # Checking ACCESION: XM_011936308.1
# 28 # Checking ACCESION: XM_034932318.1
# 29 # Checking ACCESION: XM_008955891.2
# 30 # Checking ACCESION: NM_001143810.2
# 31 # Checking ACCESION: XM_011520280.2
# 32 # Checking ACCESION: NM_001709.5
# 33 # Checking ACCESION: NM_001143813.2
# 34 # Checking ACCESION: XM_004050851.2
# 35 # Checking ACCESION: XM_009007854.3
# 36 # Checking ACCESION: XM_013019595.1
# 37 # Checking ACCESION: XM_013019596.1
# 38 # Checking ACCESION: XM_013019592.1
# 39 # Checking ACCESION: XM_013019593.1
# 40 # Checking ACCESION: XM_020177315.1
# 41 # Checking ACCESION: XM_015476449.1
# 42 # Checking ACCESION: XM_031944161.1
# 43 # Checking ACCESION: XM_023506303.2
# 44 # Checking ACCESION: XM_031944159.1
# 45 # Checking ACCESION: XM_027852578.1
# 46 # Checking ACCESION: XM_027852579.1
# 47 # Checking ACCESION: XM_020977978.1
# 48 # Checking ACCESION: XM_020977976.1
# 49 # Checking ACCESION: XM_020977979.1
# 50 # Checking ACCESION: XM_020977977.1
# 51 # Checking ACCESION: XM_036763631.1
# 52 # Checking ACCESION: XM_007497196.2
# 53 # Checking ACCESION: XM_007497203.2
# 54 # Checking ACCESION: XM_007497199.2
# 55 # Checking ACCESION: XM_029059317.2
# 56 # Checking ACCESION: XM_029059318.2
# 57 # Checking ACCESION: XM_008851139.2
# 58 # Checking ACCESION: XM_029555093.1
# 59 # Checking ACCESION: XM_008851155.2
# 60 # Checking ACCESION: XM_008851150.2
# 61 # Checking ACCESION: XM_029555090.1
# 62 # Checking ACCESION: XM_003512747.5
# 63 # Checking ACCESION: XM_035436972.1
# 64 # Checking ACCESION: XM_007653166.4
# 65 # Checking ACCESION: XM_035436971.1
# 66 # Checking ACCESION: XM_007653168.4
# 67 # Checking ACCESION: XM_037204438.1
# 68 # Checking ACCESION: XM_031371316.1
# 69 # Checking ACCESION: XM_031371317.1
# 70 # Checking ACCESION: XM_031371314.1
# 71 # Checking ACCESION: XM_031371315.1
# 72 # Checking ACCESION: XM_031371313.1
# 73 # Checking ACCESION: XM_006234684.4
# 74 # Checking ACCESION: XM_032903862.1
# 75 # Checking ACCESION: NM_001270631.1
# 76 # Checking ACCESION: NM_001270634.1
# 77 # Checking ACCESION: NM_001048142.1
# 78 # Checking ACCESION: NM_007540.4
# 79 # Checking ACCESION: NM_001285422.1
# 80 # Checking ACCESION: XM_021151236.2
# 81 # Checking ACCESION: XM_021192829.2
# 82 # Checking ACCESION: XM_032903864.1
# 83 # Checking ACCESION: XM_032903863.1
# 84 # Checking ACCESION: XM_032903866.1
# 85 # Checking ACCESION: XM_032903861.1
# 86 # Checking ACCESION: NM_001270630.1
# 87 # Checking ACCESION: NM_012513.4
# 88 # Checking ACCESION: XM_004660850.2
# 89 # Checking ACCESION: XM_004660847.2
# 90 # Checking ACCESION: XM_004660846.2
# 91 # Checking ACCESION: XM_036258710.1
# 92 # Checking ACCESION: XM_036258708.1
# 93 # Checking ACCESION: XM_036258709.1
# 94 # Checking ACCESION: XM_036258707.1
# 95 # Checking ACCESION: XM_017667612.2
# 96 # Checking ACCESION: XM_017667617.2
# 97 # Checking ACCESION: XM_017667615.2
# 98 # Checking ACCESION: XM_036879082.1
# 99 # Checking ACCESION: XM_036879081.1
# 100 # Checking ACCESION: XM_036879079.1
# 101 # Checking ACCESION: XM_004418545.2
# 102 # Checking ACCESION: XM_004418542.2
# 103 # Checking ACCESION: XM_008522868.1
# 104 # Checking ACCESION: NM_001081787.1
# 105 # Checking ACCESION: XM_014831462.1
# 106 # Checking ACCESION: XM_014831463.1
# 107 # Checking ACCESION: XM_019650719.1
# 108 # Checking ACCESION: XM_019650718.1
# 109 # Checking ACCESION: XM_019650723.1
# 110 # Checking ACCESION: XM_019650722.1
# 111 # Checking ACCESION: XM_028501147.1
# 112 # Checking ACCESION: XM_028501139.1
# 113 # Checking ACCESION: XM_028501136.1
# 114 # Checking ACCESION: XM_028501135.1
# 115 # Checking ACCESION: XM_028501134.1
# 116 # Checking ACCESION: XM_028501140.1
# 117 # Checking ACCESION: XM_028501141.1
# 118 # Checking ACCESION: XM_028501149.1
# 119 # Checking ACCESION: XM_032641483.1
# 120 # Checking ACCESION: XM_032641486.1
# 121 # Checking ACCESION: XM_032641482.1
# 122 # Checking ACCESION: XM_032641485.1
# 123 # Checking ACCESION: XM_032641484.1
# 124 # Checking ACCESION: XM_030864833.1
# 125 # Checking ACCESION: XM_027115138.1
# 126 # Checking ACCESION: XM_019947884.2
# 127 # Checking ACCESION: XM_004263943.2
# 128 # Checking ACCESION: XM_029207935.1
# 129 # Checking ACCESION: XM_029207934.1
# 130 # Checking ACCESION: XM_029207944.1
# 131 # Checking ACCESION: XM_029207936.1
# 132 # Checking ACCESION: XM_007461679.1
# 133 # Checking ACCESION: XM_007461684.1
# 134 # Checking ACCESION: XM_007461681.1
# 135 # Checking ACCESION: XM_022583733.1
# 136 # Checking ACCESION: XM_007113739.2
# 137 # Checking ACCESION: XM_007113738.2
# 138 # Checking ACCESION: XM_007180992.1
# 139 # Checking ACCESION: XM_007180993.1
# 140 # Checking ACCESION: XM_007180991.1
# 141 # Checking ACCESION: XM_036862552.1
# 142 # Checking ACCESION: XM_036862555.1
# 143 # Checking ACCESION: XM_036862554.1
# 144 # Checking ACCESION: XM_020903259.1
# 145 # Checking ACCESION: XM_020903257.1
# 146 # Checking ACCESION: XM_020903256.1
# 147 # Checking ACCESION: XM_019974522.1
# 148 # Checking ACCESION: XM_010831789.1
# 149 # Checking ACCESION: XM_010831788.1
# 150 # Checking ACCESION: XM_027562786.1
# 151 # Checking ACCESION: XM_005216334.4
# 152 # Checking ACCESION: XM_027562791.1
# 153 # Checking ACCESION: XM_027562787.1
# 154 # Checking ACCESION: XM_006068007.2
# 155 # Checking ACCESION: XM_006068006.2
# 156 # Checking ACCESION: XM_005690025.2
# 157 # Checking ACCESION: XM_005690027.2
# 158 # Checking ACCESION: XM_005690026.2
# 159 # Checking ACCESION: XM_012096129.3
# 160 # Checking ACCESION: XM_015101092.2
# 161 # Checking ACCESION: NM_214259.2
# 162 # Checking ACCESION: XM_005654684.3
# 163 # Checking ACCESION: XM_005654686.3
# 164 # Checking ACCESION: XM_021081411.1
# 165 # Checking ACCESION: XM_036427681.1
# 166 # Checking ACCESION: XM_036427677.1
# 167 # Checking ACCESION: XM_036427676.1
# 168 # Checking ACCESION: XM_036427679.1
# 169 # Checking ACCESION: XM_036427680.1
# 170 # Checking ACCESION: XM_008148948.2
# 171 # Checking ACCESION: XM_008148951.2
# 172 # Checking ACCESION: XM_008148950.2
# 173 # Checking ACCESION: XM_008148947.2
# 174 # Checking ACCESION: XM_023756375.1
# 175 # Checking ACCESION: XM_023756376.1
# 176 # Checking ACCESION: XM_023756374.1
# 177 # Checking ACCESION: XM_036325692.1
# 178 # Checking ACCESION: XM_036325691.1
# 179 # Checking ACCESION: XM_006753948.2
# 180 # Checking ACCESION: XM_006753949.2
# 181 # Checking ACCESION: XM_006753950.2
# 182 # Checking ACCESION: XM_014545223.1
# 183 # Checking ACCESION: XM_005401752.2
# 184 # Checking ACCESION: XM_005401753.2
# 185 # Checking ACCESION: XM_005401751.2
# 186 # Checking ACCESION: XM_004644115.3
# 187 # Checking ACCESION: XM_023704229.1
# 188 # Checking ACCESION: XM_004644113.2
# 189 # Checking ACCESION: XM_013074564.2
# 190 # Checking ACCESION: XM_004851581.3
# 191 # Checking ACCESION: XM_004851582.2
# 192 # Checking ACCESION: XM_033764060.1
# 193 # Checking ACCESION: XM_003465009.4
# 194 # Checking ACCESION: XM_013147264.2
# 195 # Checking ACCESION: XM_013147262.2
# 196 # Checking ACCESION: XM_016206156.1
# 197 # Checking ACCESION: XM_016206154.1
# 198 # Checking ACCESION: XM_016206157.1
# 199 # Checking ACCESION: XM_016206155.1
# 200 # Checking ACCESION: XM_010964746.1
# 201 # Checking ACCESION: XM_010964745.1
# 202 # Checking ACCESION: XM_010964743.1
# 203 # Checking ACCESION: XM_031681074.1
# 204 # Checking ACCESION: XM_031459858.1
# 205 # Checking ACCESION: XM_006195083.3
# 206 # Checking ACCESION: XM_008686880.1
# 207 # Checking ACCESION: XM_026512203.1
# 208 # Checking ACCESION: XM_037522538.1
# 209 # Checking ACCESION: XM_037522541.1
# 210 # Checking ACCESION: XM_037522540.1
# 211 # Checking ACCESION: XM_004682964.2
# 212 # Checking ACCESION: XM_012725669.1
# 213 # Checking ACCESION: XM_004682967.2
# 214 # Checking ACCESION: XM_031025064.1
# 215 # Checking ACCESION: XM_031025066.1
# 216 # Checking ACCESION: XM_031025067.1
# 217 # Checking ACCESION: XM_021685880.1
# 218 # Checking ACCESION: XM_021685881.1
# 219 # Checking ACCESION: XM_035012477.1
# 220 # Checking ACCESION: XM_036109499.1
# 221 # Checking ACCESION: XM_036109493.1
# 222 # Checking ACCESION: XM_032414178.1
# 223 # Checking ACCESION: XM_036109498.1
# 224 # Checking ACCESION: XM_032414183.1
# 225 # Checking ACCESION: XM_004408654.2
# 226 # Checking ACCESION: XM_004408655.1
# 227 # Checking ACCESION: XM_004408653.1
# 228 # Checking ACCESION: XM_027577809.1
# 229 # Checking ACCESION: XM_027577811.2
# 230 # Checking ACCESION: XM_027577807.1
# 231 # Checking ACCESION: XM_028117708.1
# 232 # Checking ACCESION: XM_028117709.1
# 233 # Checking ACCESION: XM_025879326.1
# 234 # Checking ACCESION: XM_011226480.3
# 235 # Checking ACCESION: XM_038429435.1
# 236 # Checking ACCESION: XM_038429436.1
# 237 # Checking ACCESION: XM_038429434.1
# 238 # Checking ACCESION: XM_025459816.2
# 239 # Checking ACCESION: XM_026018602.1
# 240 # Checking ACCESION: XM_026018601.1
# 241 # Checking ACCESION: XM_026018600.1
# 242 # Checking ACCESION: XM_006907989.2
# 243 # Checking ACCESION: XM_006907990.2
# 244 # Checking ACCESION: XM_006907988.2
# 245 # Checking ACCESION: XM_011362565.2
# 246 # Checking ACCESION: XM_011362569.2
# 247 # Checking ACCESION: XM_028517639.2
# 248 # Checking ACCESION: XM_036029164.1
# 249 # Checking ACCESION: XM_037146035.1
# 250 # Checking ACCESION: XM_037040421.1
# 251 # Checking ACCESION: XM_024558903.1
# 252 # Checking ACCESION: XM_024558905.1
# 253 # Checking ACCESION: XM_024558906.1
# 254 # Checking ACCESION: XM_033118944.1
# 255 # Checking ACCESION: XM_012649559.1
# 256 # Checking ACCESION: XM_012649556.1
# 257 # Checking ACCESION: XM_012814047.1
# 258 # Checking ACCESION: XM_012814097.1
# 259 # Checking ACCESION: XM_012814104.1
# 260 # Checking ACCESION: XM_003781198.1
# 261 # Checking ACCESION: XM_012814102.1
# 262 # Checking ACCESION: XM_003781199.2
# 263 # Checking ACCESION: XM_029957156.1
# 264 # Checking ACCESION: XM_029957152.1
# 265 # Checking ACCESION: XM_029957153.1
# 266 # Checking ACCESION: NM_001009828.1
# 267 # Checking ACCESION: XM_030333208.1
# 268 # Checking ACCESION: XM_015544869.1
# 269 # Checking ACCESION: XM_016194241.1
# 270 # Checking ACCESION: XM_016194242.1
# 271 # Checking ACCESION: XM_015476457.1
# 272 # Checking ACCESION: XM_015476468.1
# 273 # Checking ACCESION: XM_015476463.1
# 274 # Checking ACCESION: XM_015476489.1
# 275 # Checking ACCESION: XM_027936596.1
# 276 # Checking ACCESION: XM_027936602.1
# 277 # Checking ACCESION: XM_027936601.1
# 278 # Checking ACCESION: XM_027936597.1
# 279 # Checking ACCESION: XM_040284582.1
# 280 # Checking ACCESION: XM_040284585.1
# 281 # Checking ACCESION: XM_040284584.1
# 282 # Checking ACCESION: XM_026412275.1
# 283 # Checking ACCESION: XM_026412273.1
# 284 # Checking ACCESION: XM_026412274.1
# 285 # Checking ACCESION: XM_026412272.1
# 286 # Checking ACCESION: XM_004585441.1
# 287 # Checking ACCESION: XM_004585443.3
# 288 # Checking ACCESION: XM_004585440.1
# 289 # Checking ACCESION: XM_008584196.1
# 290 # Checking ACCESION: XM_008584191.1
# 291 # Checking ACCESION: XM_008584165.1
# 292 # Checking ACCESION: XM_008584174.1
# 293 # Checking ACCESION: XM_006864851.1
# 294 # Checking ACCESION: XM_006864852.1
# 295 # Checking ACCESION: XM_006864854.1
# 296 # Checking ACCESION: XM_004708253.2
# 297 # Checking ACCESION: XM_004708254.2
# 298 # Checking ACCESION: XM_006883714.1
# 299 # Checking ACCESION: XM_006883717.1
# 300 # Checking ACCESION: XM_006883713.1
# 301 # Checking ACCESION: XM_007951956.1
# 302 # Checking ACCESION: XM_007951955.1
# 303 # Checking ACCESION: XM_007951952.1
# 304 # Checking ACCESION: XM_004369735.2
# 305 # Checking ACCESION: XM_004369738.1
# 306 # Checking ACCESION: XM_004369733.1
# 307 # Checking ACCESION: XM_012523604.2
# 308 # Checking ACCESION: XM_014591303.2
# 309 # Checking ACCESION: XM_032283699.1
# 310 # Checking ACCESION: XM_032283692.1
# 311 # Checking ACCESION: XM_032283697.1
# 312 # Checking ACCESION: XM_032283696.1
# 313 # Checking ACCESION: XM_003919940.3
# 314 # Checking ACCESION: XM_003919943.3
# 315 # Checking ACCESION: XM_010331447.1
# 316 # Checking ACCESION: XM_035262282.1
# 317 # Checking ACCESION: XM_035262277.1
# 318 # Checking ACCESION: XM_035262276.1
# 319 # Checking ACCESION: XM_009007858.2
# 320 # Checking ACCESION: XM_035262278.1
# 321 # Checking ACCESION: XM_002755152.4
# 322 # Checking ACCESION: XM_025358306.1
# 323 # Checking ACCESION: XM_017948546.3
# 324 # Checking ACCESION: XM_023230347.2
# 325 # Checking ACCESION: XM_011936309.1
# 326 # Checking ACCESION: XM_023230357.2
# 327 # Checking ACCESION: XM_025358316.1
# 328 # Checking ACCESION: XM_025358308.1
# 329 # Checking ACCESION: XM_017948540.3
# 330 # Checking ACCESION: XM_037999558.1
# 331 # Checking ACCESION: XM_037999556.1
# 332 # Checking ACCESION: XM_008003712.2
# 333 # Checking ACCESION: XM_008003719.2
# 334 # Checking ACCESION: XM_025358307.1
# 335 # Checking ACCESION: XM_012031698.1
# 336 # Checking ACCESION: XM_011710304.1
# 337 # Checking ACCESION: XM_017948538.3
# 338 # Checking ACCESION: XM_008003703.2
# 339 # Checking ACCESION: XM_023230348.2
# 340 # Checking ACCESION: XM_011936311.1
# 341 # Checking ACCESION: XM_023230351.2
# 342 # Checking ACCESION: XM_011936307.1
# 343 # Checking ACCESION: XM_017858806.1
# 344 # Checking ACCESION: XM_017858808.1
# 345 # Checking ACCESION: XM_017858807.1
# 346 # Checking ACCESION: XM_017858805.1
# 347 # Checking ACCESION: XM_010374529.2
# 348 # Checking ACCESION: XM_010374531.2
# 349 # Checking ACCESION: XM_010374530.2
# 350 # Checking ACCESION: XM_010374533.2
# 351 # Checking ACCESION: XM_033205479.1
# 352 # Checking ACCESION: XM_033205478.1
# 353 # Checking ACCESION: XM_033205475.1
# 354 # Checking ACCESION: XM_011710309.1
# 355 # Checking ACCESION: XM_005578346.2
# 356 # Checking ACCESION: XM_015114598.2
# 357 # Checking ACCESION: XM_025358305.1
# 358 # Checking ACCESION: XM_017948537.3
# 359 # Checking ACCESION: XM_004050856.3
# 360 # Checking ACCESION: XM_004050847.2
# 361 # Checking ACCESION: XM_004050848.3
# 362 # Checking ACCESION: XM_034932316.1
# 363 # Checking ACCESION: XM_008955894.3
# 364 # Checking ACCESION: XM_008955892.2
# 365 # Checking ACCESION: XM_034932317.1
# 366 # Checking ACCESION: NM_001012441.1
# 367 # Checking ACCESION: XM_032166372.1
# 368 # Checking ACCESION: XM_032166371.1
# 369 # Checking ACCESION: XM_032166375.1
# 370 # Checking ACCESION: XM_032166373.1
# 371 # Checking ACCESION: XM_032166370.1
# 372 # Checking ACCESION: XM_003254346.2
# 373 # Checking ACCESION: XM_030829513.1
# 374 # Checking ACCESION: XM_003254348.2
# 375 # Checking ACCESION: XM_003254347.2
# 376 # Checking ACCESION: XM_009246512.2
# 377 # Checking ACCESION: XM_009246514.2
# 378 # Checking ACCESION: XM_009246513.2
# 379 # Checking ACCESION: XM_002821931.2
# 380 # Checking ACCESION: XM_037742083.1
# 381 # Checking ACCESION: XM_037742081.1
# 382 # Checking ACCESION: XM_037742078.1
# 383 # Checking ACCESION: XM_017538722.1
# 384 # Checking ACCESION: XM_032283691.1
# 385 # Checking ACCESION: XM_012452238.1
# 386 # Checking ACCESION: XM_012452246.1
# 387 # Checking ACCESION: XM_012452244.1
# 388 # Checking ACCESION: XM_012452241.1
# 389 # Checking ACCESION: XM_012452242.1

# %%
# helper functions
# The following looks up NCBI Taxon ID from Accession IDs
# Then uses that Taxon ID to get the complete taxnomic lineage of of that species.
DATA_DICT = {}
#Entrez.email = "aglucaci@gmail.com"
def main(TREE_NEWICK):
    global DATA_DICT
    t = Tree(TREE_NEWICK, format=1)
    count = 1
    
    for ACCESSION in t.get_leaf_names():
        #BRANCH_NAME = ACCESSION
        #ACCESSION = ACCESSION.split("-")[0]
        print("# Checking ACCESION:", ACCESSION)
        skip = False
        for i in DATA_DICT.keys():
            if ACCESSION == DATA_DICT[i]["ACCESSION"]:
                skip = True
                break
            #end if
        #end for
        
        if skip == True: 
            count += 1
            print("# Skipping:", ACCESSION)
            continue
        #end if
        
        try:
            handle = Entrez.esummary(db="nucleotide", id=ACCESSION, rettype="gb", retmode="text", retmax=1)
            records = Entrez.parse(handle)
        except:
            print("# error, sleeping")
            time.sleep(5)
            handle = Entrez.esummary(db="nucleotide", id=ACCESSION, rettype="gb", retmode="text", retmax=1)
            records = Entrez.parse(handle)
        #end try
        
        print("# Number of records returned:", sum(1 for r in records))
        try:
            for record in records:
                TAXON_ID = record["TaxId"]
                print(count, "Processing:", str(ACCESSION), str(TAXON_ID))
                #break
                ncbi = NCBITaxa()
                lineage = ncbi.get_lineage(TAXON_ID)
                print(lineage)
                names = ncbi.get_taxid_translator(lineage)
                DATA_DICT[str(count)] = {"BRANCH_NAME": BRANCH_NAME, "ACCESSION":ACCESSION, "TAXON_ID": TAXON_ID, "LINEAGE": [names[taxid] for taxid in lineage], "TITLE":record["Title"]}
                count += 1
            #end inner for
            
            handle.close
        except:
            print("#error repeating")
            break
            main(TREE_NEWICK)
        #end try

    #end outer for
#end method

main(TREE_NEWICK)
# Out:
# # Checking ACCESION: XM_012452239.1
# # Number of records returned: 1
# # Checking ACCESION: XM_011964726.1
# # Number of records returned: 1
# # Checking ACCESION: XM_012031702.1
# # Number of records returned: 1
# # Checking ACCESION: XM_012031697.1
# # Number of records returned: 1
# # Checking ACCESION: XM_011964715.1
# # Number of records returned: 1
# # Checking ACCESION: XM_011964723.1
# # Number of records returned: 1
# # Checking ACCESION: XM_011964717.1
# # Number of records returned: 1
# # Checking ACCESION: XM_012649562.1
# # Number of records returned: 1
# # Checking ACCESION: XM_020286536.1
# # Number of records returned: 1
# # Checking ACCESION: XM_020286535.1
# # Number of records returned: 1
# # Checking ACCESION: XM_020286537.1
# # Number of records returned: 1
# # Checking ACCESION: XM_020286540.1
# # Number of records returned: 1
# # Checking ACCESION: XM_020286534.1
# # Number of records returned: 1
# # Checking ACCESION: XM_012649557.1
# # Number of records returned: 1
# # Checking ACCESION: XM_012649566.1

# %%
#Main subroutine

# %%
import pandas as pd
df = pd.DataFrame.from_dict(DATA_DICT, orient="index")
df

#df.to_csv("../results/BDNF_lineage.csv")

# %%
df

# %% [markdown]
# ## Orders

# %%
# 19 Mammalian Orders
# https://culter.colorado.edu/~kittel/WEcol_Handouts/MammalOrders_Sheryn06.pdf
# https://en.wikipedia.org/wiki/Mammal_classification
#https://byjus.com/biology/mammalia-diversity-in-living-organisms/

# Eutheria
# Metatheria
# Prototheria
# https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=40674
Mammalia_Orders = ["Monotremata",
                  "Afrotheria",
                  "Boreoeutheria",
                  "Litopterna",
                  "Notoungulata",
                  "Xenarthra",
                  "Dasyuromorphia",
                  "Didelphimorphia",
                  "Diprotodontia",
                  "Microbiotheria",
                  "Notoryctemorphia",
                  "Paucituberculata",
                  "Peramelemorphia"]

"""
Mammalia_Orders = ["Artiodactyla",
                  "Carnivora",
                  "Cetacea",
                  "Chiroptera",
                  "Dermoptera",
                  "Edentata",
                  "Hyracoidae",
                  "Insectivora",
                  "Lagomorpha",
                  "Marsupialia",
                  "Monotremata",
                  "Perissodactyla",
                  "Pholidata",
                  "Pinnipedia",
                  "Primates",
                  "Proboscidea",
                  "Rodentia",
                  "Sirenia",
                  "Tubulidentata"]
"""

# %%
order_list = []
for n,item in enumerate(df["LINEAGE"]):
    #print(n,type(item))
    count = 0
    for classification in item:
        #print(classification)
        if classification in Mammalia_Orders:
            count += 1
            order_list.append(classification)
            if count > 1:
                print(n+1, item, classification)
        #end if
    #end for
    if count == 0:
        order_list.append("NaN")
        print(n+1, item, classification)
#end for

df["Order"] = order_list

# %%
df.Order.value_counts()

# %%
df.Order.nunique()

# %%
df.Order.shape

# %%
df.Order.value_counts().plot.pie(startangle=0, legend=False, shadow=True, subplots=True, figsize=(9, 9), autopct='%1.1f%%')

# %% [markdown]
# ## Closer Order

# %%
Mammalia_Orders_Closer = ["Dermoptera",
                  "Glires",
                  "Primates",
                  "Scandentia",
                  "Artiodactyla",
                  "Carnivora",
                  "Chiroptera",
                  "Eulipotyphla",
                  "Perissodactyla",
                  "Pholidota", #ends boroeutheria
                  "Ornithorhynchidae",
                  "Tachyglossidae", # ends Monotremata
                  "Chrysochloridae",
                  "Hyracoidea",
                  "Macroscelidea",
                  "Proboscidea",
                  "Sirenia",
                  "Tenrecidae",
                  "Tubulidentata", # ends Afrotheria
                  "Macraucheniidae", #ends Litopterna
                  "Toxodontidae", # ends Notoungulata
                  "Pilosa",
                  "Cingulata", # ends Xenarthra
                  "Dasyuridae",
                  "Myrmecobiidae",
                  "Thylacinidae", #ends Dasyuromorphia
                  "Didelphidae", # ends Didelphimorphia
                  "Acrobatidae",
                  "Burramyidae",
                  "Macropodidae",
                  "Petauridae",
                  "Phalangeridae",
                  "Phascolarctidae",
                  "Potoroidae",
                  "Pseudocheiridae",
                  "Tarsipedidae",
                  "Vombatidae", # ends Diprotodontia
                  "Microbiotheriidae", #ends  Microbiotheria
                  "Notoryctidae", #ends  Notoryctemorphia
                  "Caenolestidae",# ends Paucituberculata
                  "Peramelidae",
                  "Peroryctidae" #ends Peramelemorphia
                  ]

# %%
order_list = []
for n, item in enumerate(df["LINEAGE"]):
    #print(n,type(item))
    count = 0
    for classification in item:
        #print("## TRYING:", n+1, classification)
        #print(classification)
        if classification in Mammalia_Orders_Closer:
            count += 1
            order_list.append(classification)
            #print("## MATCH:", n+1, item, classification)
            if count > 1:
                print("## DOUBLE:", n+1, item, classification)
        #end if
    #end for
    
    if count == 0:
        #print("## NO MATCH:", n+1, item, classification)
        order_list.append("NaN")
        print()
#end for

df["Order"] = order_list
df.Order.value_counts().plot.pie(startangle=0, legend=False, shadow=True, subplots=True, figsize=(9, 9), autopct='%1.1f%%')

# %%
df

# %%
df.Order.value_counts()

# %%
for item in df.Order.unique():
    print(item)
    df3 = df[df["Order"] == item]
    #print(df3.shape)
    output = "../results/" + item + ".txt"
    # get the taxa names
    np.savetxt(output, df3.BRANCH_NAME.values, fmt='%s')

# %%
# save it
import numpy as np
df3 = df[df[]]

np.savetxt("../results/suborder.txt", df.Order.values, fmt='%s')

# %% [markdown]
# ## Break down Primates

# %%
def classify(data, GROUPS):
    order_list = []
    for n, item in enumerate(data):
        count = 0
        for classification in item:
            if classification in GROUPS:
                count += 1
                order_list.append(classification)
                #print("## MATCH:", n+1, item, classification)
                if count > 1:
                    print("## DOUBLE:", n+1, item, classification)
            #end if
        #end for
    
        if count == 0:
            #print("## NO MATCH:", n+1, item, classification)
            order_list.append("NaN")
            print()
        #end if
    #end for
    return order_list
#end method

# %%
df2 = df[df["Order"] == "Primates"]
Primates_SubOrder = ["Haplorrhini", "Strepsirrhini"]

df2["SubOrder"] = classify(df2["LINEAGE"], Primates_SubOrder)
#df2["SubOrder"].value_counts().plot()
df2["SubOrder"].value_counts().plot.pie()

# %%
df2 = df[df["Order"] == "Primates"]
Primates_SubOrder = ["Simiiformes", "Tarsiiformes", "Chiromyiformes", "Lemuriformes", "Lorisiformes"]

df2["SubOrder"] = classify(df2["LINEAGE"], Primates_SubOrder)
#df2["SubOrder"].value_counts().plot()
df2["SubOrder"].value_counts().plot.pie()

# %%
df2 = df[df["Order"] == "Primates"]
Primates_SubOrder = ["Catarrhini", "Platyrrhini", "Tarsiidae", 
                     "Daubentoniidae", "Cheirogaleidae", "Indriidae",
                    "Lemuridae", "Lepilemuridae", "Paleopropithecidae",
                    "Galagidae", "Lorisidae"]

df2["SubOrder"] = classify(df2["LINEAGE"], Primates_SubOrder)
#df2["SubOrder"].value_counts().plot()
df2["SubOrder"].value_counts().plot.pie()

# %% [markdown]
# ## Tree manipulation, changing the leaf filenames
# #### Mostly, change accession to Taxon ID. Useful for iTOL.

# %%
TREE_NEWICK_TAXONIDs = TREE_NEWICK
TREE_NEWICK_TAXONIDs

# %%
t = Tree(TREE_NEWICK_TAXONIDs);
count = 1
    
for ACCESSION in t.get_leaf_names():
    #print("# Checking", ACCESSION)


    for i in DATA_DICT.keys():
        #print(i, DATA_DICT[i]["ACCESSION"])
        if ACCESSION == DATA_DICT[i]["ACCESSION"]:
            #print("\t", DATA_DICT[i]["TAXON_ID"])
            
            
            TREE_NEWICK_TAXONIDs = TREE_NEWICK_TAXONIDs.replace(str(ACCESSION), str(DATA_DICT[i]["TAXON_ID"]))
            if ACCESSION in TREE_NEWICK_TAXONIDs: print("\t", "match found")
        #end if
    #end for
#end outer for

print("# Done")

# %%
type(TREE_NEWICK_TAXONIDs)

# %%
TREE_NEWICK_TAXONIDs

# %%
TREE_NEWICK_SpeciesNames = TREE_NEWICK

t = Tree(TREE_NEWICK_SpeciesNames);
count = 1
    
for ACCESSION in t.get_leaf_names():
    #print("# Checking", ACCESSION)


    for i in DATA_DICT.keys():
        #print(i, DATA_DICT[i]["ACCESSION"])
        if ACCESSION == DATA_DICT[i]["ACCESSION"]:
            #print("\t", DATA_DICT[i]["LINEAGE"][-1])
            
            
            TREE_NEWICK_SpeciesNames = TREE_NEWICK_SpeciesNames.replace(str(ACCESSION), str(DATA_DICT[i]["LINEAGE"][-1]))
            #if ACCESSION in TREE_NEWICK_TAXONIDs: print("\t", "match found")
        #end if
    #end for
#end outer for


print(TREE_NEWICK_SpeciesNames)

# %%
TREE_NEWICK_SpeciesNames_withAnnotation = TREE_NEWICK

t = Tree(TREE_NEWICK_SpeciesNames_withAnnotation);
count = 1
    
for ACCESSION in t.get_leaf_names():
    for i in DATA_DICT.keys():
        if ACCESSION == DATA_DICT[i]["ACCESSION"]:
            LINEAGE = DATA_DICT[i]["LINEAGE"][-6]
            #TREE_NEWICK_SpeciesNames_withAnnotation = TREE_NEWICK_SpeciesNames.replace(str(ACCESSION), str(DATA_DICT[i]["LINEAGE"][-1]))
            TREE_NEWICK_SpeciesNames_withAnnotation = TREE_NEWICK_SpeciesNames_withAnnotation.replace(str(ACCESSION), str(DATA_DICT[i]["LINEAGE"][-1]) + "{" + LINEAGE +"}")
        #end if
    #end for
#end outer for

TREE_NEWICK_SpeciesNames_withAnnotation = TREE_NEWICK_SpeciesNames_withAnnotation.replace(" ", "")
print(TREE_NEWICK_SpeciesNames_withAnnotation)
